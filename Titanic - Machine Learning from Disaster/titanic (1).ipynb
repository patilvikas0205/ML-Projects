# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
train_data=pd.read_csv("/kaggle/input/clean-data-2/train_clean_data1_new.csv")

# %%
test_data=pd.read_csv("/kaggle/input/clean-data-2/test_clean_data_new.csv")

# %%
train_data.shape

# %%
test_data.shape

# %%
train_data.info()

# %%
test_data.info()

# %%
y=train_data["Survived"]
train_data.drop("Survived",axis=1,inplace=True)

# %%
train_data.shape

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier()

# %%
model.fit(train_data.drop("PassengerId",axis=1),y)

# %%
y_predict=model.predict(test_data.drop("PassengerId",axis=1))

# %%
model.score(train_data.drop("PassengerId",axis=1),y),model.score(test_data.drop("PassengerId",axis=1),y_predict)

# %%
output=pd.DataFrame({"PassengerId":test_data["PassengerId"],"Survived":y_predict})

# %%
output

# %%
output.to_csv("Submission_1.csv",index=False)

# %%
from xgboost import XGBClassifier
xgb_model=XGBClassifier()

# %%
xgb_model.fit(train_data.drop("PassengerId",axis=1),y)

# %%
y_xgbpredict=xgb_model.predict(test_data.drop("PassengerId",axis=1))

# %%
model.score(train_data.drop("PassengerId",axis=1),y),model.score(test_data.drop("PassengerId",axis=1),y_xgbpredict)

# %%
output=pd.DataFrame({"PassengerId":test_data["PassengerId"],"Survived":y_xgbpredict})

# %%
output.to_csv("Submissionxgb_1.csv",index=False)

# %%
from sklearn.model_selection import RandomizedSearchCV# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rf_random = RandomizedSearchCV(estimator = rf_model, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)# Fit the random search model

# %%
rf_random.fit(train_data.drop("PassengerId",axis=1),y)

# %%
y_rf_random_predict=rf_random.predict(test_data.drop("PassengerId",axis=1))

# %%
output=pd.DataFrame({"PassengerId":test_data["PassengerId"],"Survived":y_rf_random_predict})

# %%
output.to_csv("Submissionrfhyper_2.csv",index=False)

# %%
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

# %%
xgb_random=RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=100, scoring='roc_auc', n_jobs=4, cv=3, verbose=3, random_state=1)

# %%
xgb_random.fit(train_data.drop(["Embarked_Q","PassengerId","SibSp"],axis=1),y)

# %%
xgb_random.best_params_

# %%
y_xgb_random_predict=xgb_random.predict(test_data.drop(["Embarked_Q","PassengerId","SibSp"],axis=1))

# %%
output=pd.DataFrame({"PassengerId":test_data["PassengerId"],"Survived":y_xgb_random_predict})

# %%
output.to_csv("XGB_Hyper_Prdict1.csv",index=False)
